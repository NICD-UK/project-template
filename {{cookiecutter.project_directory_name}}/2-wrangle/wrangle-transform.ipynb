# %% [markdown]
# ## Load Libraries

# %%
import pandas
from pathlib import Path

# %% [markdown]
# ## Setup

# %%
user = "user-name"
root_path = Path(f"/home/jupyter-{user}/bootcamp")
data_name = "income"

# %% [markdown]
# ## Read Data

# %%
clean_data = pandas.read_pickle(root_path / f"data/clean/{data_name}.pkl")

# %% [markdown]
# ## Wrangle Data

# %% [markdown]
# ### Filter Rows

# %%
clean_data = clean_data.dropna()

# %% [markdown]
# ### Select Columns

# %%
clean_data = clean_data.drop(columns=[
    'final_weight',
    'education_code',
])

# %% [markdown]
# ## Write Data

# %%
clean_data.to_pickle(root_path / f"data/wrangle/{data_name}.pkl")
